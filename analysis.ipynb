# %% [markdown]
# ### Input
#
# * data/processed/etl_1-3_hw_identifying_tb.csv
# * data/processed/etl_2_twoyo_under_tack.csv
#
# ### Output
# * data/processed/analysis_deaths_by_state_racetrack_2023.csv
# * data/processed/analysis_undertack_counts.csv
# * data/processed/analysis_state_counts_2023.csv

# %%
import pandas as pd
import numpy as np

processed = "data//processed//"
manual = "data//manual//"


deaths_w_breed = pd.read_csv(processed+"etl_1-3_hw_identifying_tb.csv")
tb_2023 = deaths_w_breed[deaths_w_breed.TB.isin(['T', 'T and Q'])]

print("\nDEATHS BY BREED")
print(deaths_w_breed.TB.value_counts())
print("\nTHOROUGHBRED & 'T & Q' HORSES")
print(tb_2023['name'].count())

tb_2023.to_csv(processed + "analysis_tb_2023_racing_training.csv", index = None)

by_state = pd.pivot_table(tb_2023, index='State', columns = 'race_train_stall', values = 'name', aggfunc='count').reset_index()
by_state['T'] = by_state['T'].replace(np.nan, 0)
by_state.columns.name = None
by_state.columns = ['State', 'Racing Deaths', 'Training Deaths']
by_state['Total Deaths'] = by_state['Racing Deaths'] + by_state['Training Deaths']
by_state.to_csv(processed + "analysis_state_counts_2023.csv", index=None)

by_state_and_track = tb_2023.groupby(['State', 'track'])['name'].count().reset_index()
by_state_and_track.columns = ['State', 'Track', '2023 # of Thoroughbreds Dead from Training or Racing (so far)']
by_state_and_track.to_csv(processed + "analysis_deaths_by_state_racetrack_2023.csv",index=None)

pd.DataFrame(["SOURCE: Scripps News Analysis of Horseracing Wrongs, Equibase, and Pedigree Query data"]).to_csv(processed + "analysis_deaths_by_state_racetrack_2023.csv", mode= 'a', index=None)
# Out:
# DEATHS BY BREED
# TB
# T          295
# Q           35
# H           12
# T and Q      3
# unclear      2
# Name: count, dtype: int64
#
# THOROUGHBRED & 'T & Q' HORSES
# 298

# %%
by_state
# Out:
#             State  Racing Deaths  Training Deaths  Total Deaths
# 0         Arizona           11.0              6.0          17.0
# 1        Arkansas            9.0              6.0          15.0
# 2      California           13.0             22.0          35.0
# 3        Delaware            5.0              0.0           5.0
# 4         Florida            7.0              0.0           7.0
# 5        Illinois            6.0              5.0          11.0
# 6         Indiana            3.0              1.0           4.0
# 7        Kentucky           24.0             11.0          35.0
# 8       Louisiana           10.0              0.0          10.0
# 9        Maryland            7.0              8.0          15.0
# 10     New Jersey            4.0              1.0           5.0
# 11     New Mexico            4.0              2.0           6.0
# 12       New York           35.0             12.0          47.0
# 13   North Dakota            1.0              0.0           1.0
# 14           Ohio           14.0              6.0          20.0
# 15         Oregon            2.0              0.0           2.0
# 16   Pennsylvania           12.0              9.0          21.0
# 17          Texas            5.0              5.0          10.0
# 18       Virginia            2.0              0.0           2.0
# 19     Washington            1.0              0.0           1.0
# 20  West Virginia           19.0              9.0          28.0
# 21        Wyoming            1.0              0.0           1.0

# %%
print("\n2023 THOROUGHBRED RACING OR\nTRAINING RELATED DEATHS")
print(tb_2023.State.value_counts(dropna=False))
# Out:
# 2023 THOROUGHBRED RACING OR
# TRAINING RELATED DEATHS
# State
# New York         47
# Kentucky         35
# California       35
# West Virginia    28
# Pennsylvania     21
# Ohio             20
# Arizona          17
# Arkansas         15
# Maryland         15
# Illinois         11
# Texas            10
# Louisiana        10
# Florida           7
# New Mexico        6
# New Jersey        5
# Delaware          5
# Indiana           4
# Virginia          2
# Oregon            2
# Wyoming           1
# North Dakota      1
# Washington        1
# Name: count, dtype: int64

# %% [markdown]
# ## Under tacking
#
# Mostly trying to figure out whether we can use the number of horses sold at the Bloodhorse auctions as a measure of the number of horses that breezed. (basically trying to figure out if the number of horses that breezed+were withdrawn is larger than the number of horses that were not breezed + sold/RNAed)

# %%
FULL_DATA_TYPES = ["FT","OBS","API"]
undertack = pd.read_csv(processed+"etl_2_twoyo_under_tack.csv")
undertack["full_data"] = undertack["type"].isin(FULL_DATA_TYPES)
full_data_ut = undertack[undertack["full_data"]]

print("Far fewer horses are sold or rna at undertack shows without being breezed, than are breezed and withdrawn.")
print(full_data_ut.pivot_table(index="breezed",columns="sale_status",values="file",aggfunc="count"))
# Out:
# Far fewer horses are sold or rna at undertack shows without being breezed, than are breezed and withdrawn.
# sale_status   na     rna     sold  withdrawn
# breezed
# False        1.0    49.0    168.0     5554.0
# True         NaN  3025.0  12336.0     1419.0

# %%
# Summarize by file
def get_counts(df):
    return pd.Series([len(df), (df["sale_status"]=="sold").sum(), (df["breezed"]=="True").sum(), ((df["sale_status"]=="sold")&(df["breezed"]=="False")).sum(), ((df["sale_status"]!="sold")&(df["breezed"]=="True")).sum()], index=["total","sold","breezed","sold_not_breezed","breezed_not_sold"])


ut_counts = undertack.groupby(["file","full_data"]).apply(get_counts).reset_index()
ut_counts.to_csv(processed+"analysis_undertack_counts.csv",index=None)

print("For the undertack shows where we have full data on horses sold and horses breezed, the number of horses sold and not breezed is always lower than the number of horses breezed and not sold.")
full_data_counts = ut_counts[ut_counts["full_data"]]
full_data_counts["sold_underest_breezed"] = full_data_counts["breezed_not_sold"] > full_data_counts["sold_not_breezed"]
full_data_counts
# Out:
# For the undertack shows where we have full data on horses sold and horses breezed, the number of horses sold and not breezed is always lower than the number of horses breezed and not sold.
# /var/folders/n1/qf74t1dj555cgs6f_mhz9nm0m6xrwl/T/ipykernel_90323/3963028621.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_data_counts["sold_underest_breezed"] = full_data_counts["breezed_not_sold"] > full_data_counts["sold_not_breezed"]
#                                                  file  full_data  total  sold
# 2                                     Apr19_Excel.xls       True   1219   674  \
# 3                                     Apr20_Excel.xls       True   1312   634
# 4                                     Apr21_Excel.xls       True   1214   724
# 5                                    Apr22_Excel.xlsx       True   1230   705
# 6                                     Apr23_Excel.xls       True   1222   699
# 7                                   April18_Excel.xls       True   1220   698
# 12                                    Jul20_Excel.xls       True   1110   523
# 13                                    Jun19_Excel.xls       True   1058   624
# 14                                    Jun21_Excel.xls       True    926   575
# 15                                    Jun22_Excel.xls       True   1130   671
# 16                                    Jun23_Excel.xls       True   1087   645
# 17                                   June18_Excel.xls       True    934   535
# 19                                    Mar18_Excel.xls       True    572   257
# 20                                    Mar19_Excel.xls       True    575   306
# 21                                    Mar20_Excel.xls       True    681   294
# 22                                    Mar21_Excel.xls       True    561   325
# 23                                    Mar22_Excel.xls       True    635   374
# 24                                    Mar23_Excel.xls       True    830   464
# 25  Midlantic June Two-Year-Olds in Training (2023...       True     99    59
# 26  Midlantic May Two-Year-Olds in Training (2023)...       True    598   375
# 27     Midlantic Two-Year-Olds in Training (2018).csv       True    597   333
# 28     Midlantic Two-Year-Olds in Training (2019).csv       True    596   326
# 29     Midlantic Two-Year-Olds in Training (2020).csv       True    559   303
# 30     Midlantic Two-Year-Olds in Training (2021).csv       True    583   357
# 31     Midlantic Two-Year-Olds in Training (2022).csv       True    636   391
# 32   Santa Anita Two-Year-Olds in Training (2019).csv       True    168    69
# 33   Santa Anita Two-Year-Olds in Training (2021).csv       True    112    53
# 34                     The Gulfstream Sale (2018).csv       True    162    61
# 35                     The Gulfstream Sale (2019).csv       True    186    59
# 36                     The Gulfstream Sale (2021).csv       True    182    67
# 37                     The Gulfstream Sale (2022).csv       True    100    35
# 38  https://tcapiodata.azurewebsites.net/odata/Sal...       True    121    91
# 39  https://tcapiodata.azurewebsites.net/odata/Sal...       True    144    90
# 40  https://tcapiodata.azurewebsites.net/odata/Sal...       True    193   108
#
#     breezed  sold_not_breezed  breezed_not_sold  sold_underest_breezed
# 2      1001                 0               327                   True
# 3       777                 1               144                   True
# 4       864                 0               140                   True
# 5       900                 0               195                   True
# 6       876                 0               177                   True
# 7       959                 0               261                   True
# 12      639                13               129                   True
# 13      749                19               144                   True
# 14      733                 8               166                   True
# 15      888                18               235                   True
# 16      852                16               223                   True
# 17      664                 7               136                   True
# 19      459                 0               202                   True
# 20      479                 0               173                   True
# 21      481                 0               187                   True
# 22      406                 2                83                   True
# 23      485                 0               111                   True
# 24      682                 0               218                   True
# 25       82                 2                25                   True
# 26      483                 5               113                   True
# 27      483                 1               151                   True
# 28      481                 0               155                   True
# 29      401                 8               106                   True
# 30      460                 6               109                   True
# 31      543                 3               155                   True
# 32       93                11                35                   True
# 33       69                 3                19                   True
# 34      112                 3                54                   True
# 35      120                 5                66                   True
# 36      131                 6                70                   True
# 37       70                 0                35                   True
# 38       99                 6                14                   True
# 39      111                10                31                   True
# 40      148                15                55                   True

# %%
# Summarize by file
def get_counts(df):
    return pd.Series([len(df), (df["sale_status"].isin(["sold","rna"])).sum(), (df["breezed"]=="True").sum(), ((df["sale_status"].isin(["sold","rna"]))&(df["breezed"]=="False")).sum(), ((df["sale_status"]=="withdrawn")&(df["breezed"]=="True")).sum()], index=["total","sold+rna","breezed","sold+rna_not_breezed","breezed_withdrawn"])


ut_counts = undertack.groupby(["file","full_data"]).apply(get_counts).reset_index()
#ut_counts.to_csv(processed+"analysis_1_undertack_counts.csv",index=None)

print("Same thing but sold+rna")
full_data_counts = ut_counts[ut_counts["full_data"]]
full_data_counts["sold_underest_breezed"] = full_data_counts["breezed_withdrawn"] > full_data_counts["sold+rna_not_breezed"]
full_data_counts.sort_values("sold_underest_breezed")
# Out:
# Same thing but sold+rna
# /var/folders/n1/qf74t1dj555cgs6f_mhz9nm0m6xrwl/T/ipykernel_90323/2642894085.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_data_counts["sold_underest_breezed"] = full_data_counts["breezed_withdrawn"] > full_data_counts["sold+rna_not_breezed"]
#                                                  file  full_data  total
# 40  https://tcapiodata.azurewebsites.net/odata/Sal...       True    193  \
# 3                                     Apr20_Excel.xls       True   1312
# 38  https://tcapiodata.azurewebsites.net/odata/Sal...       True    121
# 39  https://tcapiodata.azurewebsites.net/odata/Sal...       True    144
# 21                                    Mar20_Excel.xls       True    681
# 12                                    Jul20_Excel.xls       True   1110
# 13                                    Jun19_Excel.xls       True   1058
# 32   Santa Anita Two-Year-Olds in Training (2019).csv       True    168
# 17                                   June18_Excel.xls       True    934
# 29     Midlantic Two-Year-Olds in Training (2020).csv       True    559
# 30     Midlantic Two-Year-Olds in Training (2021).csv       True    583
# 31     Midlantic Two-Year-Olds in Training (2022).csv       True    636
# 33   Santa Anita Two-Year-Olds in Training (2021).csv       True    112
# 34                     The Gulfstream Sale (2018).csv       True    162
# 35                     The Gulfstream Sale (2019).csv       True    186
# 36                     The Gulfstream Sale (2021).csv       True    182
# 37                     The Gulfstream Sale (2022).csv       True    100
# 28     Midlantic Two-Year-Olds in Training (2019).csv       True    596
# 27     Midlantic Two-Year-Olds in Training (2018).csv       True    597
# 2                                     Apr19_Excel.xls       True   1219
# 25  Midlantic June Two-Year-Olds in Training (2023...       True     99
# 24                                    Mar23_Excel.xls       True    830
# 22                                    Mar21_Excel.xls       True    561
# 20                                    Mar19_Excel.xls       True    575
# 19                                    Mar18_Excel.xls       True    572
# 16                                    Jun23_Excel.xls       True   1087
# 15                                    Jun22_Excel.xls       True   1130
# 14                                    Jun21_Excel.xls       True    926
# 7                                   April18_Excel.xls       True   1220
# 6                                     Apr23_Excel.xls       True   1222
# 5                                    Apr22_Excel.xlsx       True   1230
# 4                                     Apr21_Excel.xls       True   1214
# 26  Midlantic May Two-Year-Olds in Training (2023)...       True    598
# 23                                    Mar22_Excel.xls       True    635
#
#     sold+rna  breezed  sold+rna_not_breezed  breezed_withdrawn
# 40       167      148                    25                  6  \
# 3        778      777                     1                  0
# 38       104       99                     8                  3
# 39       119      111                    14                  6
# 21       482      481                     1                  0
# 12       654      639                    15                  0
# 13       768      749                    19                  0
# 32       108       93                    20                  5
# 17       673      664                     9                  0
# 29       375      401                     9                 35
# 30       426      460                     6                 40
# 31       482      543                     3                 64
# 33        68       69                     4                  5
# 34        91      112                     6                 27
# 35       100      120                    10                 30
# 36       105      131                     7                 33
# 37        52       70                     0                 18
# 28       425      481                     0                 56
# 27       430      483                     1                 54
# 2        840     1001                     0                161
# 25        79       82                     2                  5
# 24       585      682                     0                 97
# 22       389      406                     2                 19
# 20       402      479                     0                 77
# 19       363      459                     0                 96
# 16       770      852                    17                 99
# 15       810      888                    21                 99
# 14       695      733                    12                 50
# 7        861      959                     0                 98
# 6        840      876                     0                 36
# 5        837      900                     0                 63
# 4        833      864                     0                 31
# 26       437      483                     5                 51
# 23       430      485                     0                 55
#
#     sold_underest_breezed
# 40                  False
# 3                   False
# 38                  False
# 39                  False
# 21                  False
# 12                  False
# 13                  False
# 32                  False
# 17                  False
# 29                   True
# 30                   True
# 31                   True
# 33                   True
# 34                   True
# 35                   True
# 36                   True
# 37                   True
# 28                   True
# 27                   True
# 2                    True
# 25                   True
# 24                   True
# 22                   True
# 20                   True
# 19                   True
# 16                   True
# 15                   True
# 14                   True
# 7                    True
# 6                    True
# 5                    True
# 4                    True
# 26                   True
# 23                   True

# %%
horses_breezed = undertack[undertack["breezed"]=="True"]["file"].count()
horses_sold_bh_data = undertack[(undertack["type"]=="BH")&(undertack["sale_status"]=="sold")]["file"].count()
print("Horses breezed:",horses_breezed)
print("Horses sold in BH auctions (no breeze data):",horses_sold_bh_data)
print("both",horses_breezed+horses_sold_bh_data)
# Out:
# Horses breezed: 16990
# Horses sold in BH auctions (no breeze data): 223
# both 17213
